# %% [markdown]
# ## Installing the required libraries
# * installing unsloth with required libraries can give you lot of issues make sure you follow the similar sequence used below.

# %%
# Run this first (cell 1)
# !python -m pip install --upgrade pip
# !pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install xformers[torch2]  # Install xformers built for PyTorch 2.x
# !pip install "unsloth[colab] @ git+https://github.com/unslothai/unsloth.git"
# !pip install "git+https://github.com/huggingface/transformers.git"
# !pip install trl
# !pip install boto3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
# WARNING: xformers 0.0.28.post3 does not provide the extra 'torch2'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 120.3 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-o_xwz4l5/unsloth_1a5f9d303a454d938324479b9fd16ed3
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-o_xwz4l5/unsloth_1a5f9d303a454d938324479b9fd16ed3
#   Resolved https://github.com/unslothai/unsloth.git to commit 8558bc92b06f9128499484ef737fa71b966ffc23
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# run this cell (cell 2)
# !pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118  # Upgrade PyTorch to a compatible version
# !pip install xformers  # Install xformers after upgrading PyTorch
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 838.3/838.3 MB 26.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 33.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 30.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 49.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 42.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 43.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 66.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 43.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 67.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 72.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 MB 62.0 MB/s eta 0:00:00
# ...

# %%
# cell 3
# !pip uninstall torch torchvision torchaudio -y # Uninstall existing PyTorch, torchvision and torchaudio
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118  # Install PyTorch, torchvision and torchaudio with CUDA 11.8
# Out:
# Found existing installation: torch 2.1.0
# Uninstalling torch-2.1.0:
#   Successfully uninstalled torch-2.1.0
# Found existing installation: torchvision 0.20.1+cu121
# Uninstalling torchvision-0.20.1+cu121:
#   Successfully uninstalled torchvision-0.20.1+cu121
# Found existing installation: torchaudio 2.5.1+cu121
# Uninstalling torchaudio-2.5.1+cu121:
#   Successfully uninstalled torchaudio-2.5.1+cu121
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#   Using cached https://download.pytorch.org/whl/cu118/torch-2.5.1%2Bcu118-cp310-cp310-linux_x86_64.whl (838.3 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 62.7 MB/s eta 0:00:00
# ...
#   Using cached https://download.pytorch.org/whl/triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 2.1.0
#     Uninstalling triton-2.1.0:
# ...

# %%
# cell 4
# !pip uninstall xformers -y
# !pip install xformers[torch2]  # Install xformers built for PyTorch 2.x
# Out:
# Found existing installation: xformers 0.0.22.post7
# Uninstalling xformers-0.0.22.post7:
#   Successfully uninstalled xformers-0.0.22.post7
# ...
#   Using cached xformers-0.0.28.post3-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# WARNING: xformers 0.0.28.post3 does not provide the extra 'torch2'
# ...
# Using cached xformers-0.0.28.post3-cp310-cp310-manylinux_2_28_x86_64.whl (16.7 MB)
# ...

# %% [markdown]
# ## Importing Necessary Libraries

# %%
# Import necessary libraries for instruction fine-tuning
from unsloth import FastLanguageModel
from trl import SFTTrainer
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments
import os
import torch
from datasets import load_dataset
from peft import PeftModel
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %% [markdown]
# ## Loading the Model

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 2048
dtype = None  # Auto detection of dtype
load_in_4bit = True  # Reduce memory usage with 4-bit quantization

quantized_model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/Llama-3.2-3B-Instruct",
    max_seq_length=max_seq_length,
    dtype=dtype,
    load_in_4bit=load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2024.11.10: Fast Llama patching. Transformers:4.47.0.dev0.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu118. CUDA: 7.5. CUDA Toolkit: 11.8. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/54.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]

# %% [markdown]
# ## Applying LORA

# %%
#change name to lora model here
lora_layers_and_quantized_model = FastLanguageModel.get_peft_model(
    quantized_model,
    r=16,  # LoRA rank
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    lora_alpha=16,
    lora_dropout=0,  # Optimized at 0
    bias="none",  # No additional bias terms
    use_gradient_checkpointing="unsloth",  # Gradient checkpointing to save memory
    random_state=3407,
    use_rslora=False,  # Rank stabilized LoRA, can be enabled for stability
)
# Out:
# Unsloth 2024.11.10 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.

# %% [markdown]
# ## Dataset Preparation

# %%
from datasets import load_dataset
dataset = load_dataset("charanhu/kannada-instruct-dataset-390-k", split="train")
from unsloth.chat_templates import standardize_sharegpt
dataset = standardize_sharegpt(dataset)
# Out:
# README.md:   0%|          | 0.00/358 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/130M [00:00<?, ?B/s]
# ...
# Standardizing format:   0%|          | 0/389608 [00:00<?, ? examples/s]

# %%
for i in dataset:
  print(i)
  break
# Out:
# {'conversations': [{'content': 'ಆರೋಗ್ಯವಾಗಿರಲು ಮೂರು ಸಲಹೆಗಳನ್ನು ನೀಡಿ.', 'role': 'user'}, {'content': '1.Eat ಸಮತೋಲಿತ ಆಹಾರ ಮತ್ತು ಸಾಕಷ್ಟು ಹಣ್ಣುಗಳು ಮತ್ತು ತರಕಾರಿಗಳನ್ನು ಸೇರಿಸುವುದನ್ನು ಖಚಿತಪಡಿಸಿಕೊಳ್ಳಿ. 2. ನಿಮ್ಮ ದೇಹವನ್ನು ಸಕ್ರಿಯವಾಗಿ ಮತ್ತು ಸದೃಢವಾಗಿಡಲು ನಿಯಮಿತವಾಗಿ ವ್ಯಾಯಾಮ ಮಾಡಿ. 3. ಸಾಕಷ್ಟು ನಿದ್ರೆ ಪಡೆಯಿರಿ ಮತ್ತು ಸ್ಥಿರವಾದ ನಿದ್ರೆಯ ವೇಳಾಪಟ್ಟಿಯನ್ನು ಕಾಪಾಡಿಕೊಳ್ಳಿ.', 'role': 'assistant'}]}

# %% [markdown]
# ## Data Formatting  (what model expects for instruction tuning)

# %%
# tokenizer will be used directly, to format the data,, it won't tokenize it only formatting will be done by(tokenizer side)
def formatting_prompts_func(examples):
 convos = examples["conversations"]
 texts = [tokenizer.apply_chat_template(convo, tokenize=False, add_generation_prompt=False) for convo in convos]
 return { "text": texts }
dataset = dataset.map(formatting_prompts_func, batched=True)
# Out:
# Map:   0%|          | 0/389608 [00:00<?, ? examples/s]

# %%
for i in dataset:
  print(i)
  break
# Out:
# {'conversations': [{'content': 'ಆರೋಗ್ಯವಾಗಿರಲು ಮೂರು ಸಲಹೆಗಳನ್ನು ನೀಡಿ.', 'role': 'user'}, {'content': '1.Eat ಸಮತೋಲಿತ ಆಹಾರ ಮತ್ತು ಸಾಕಷ್ಟು ಹಣ್ಣುಗಳು ಮತ್ತು ತರಕಾರಿಗಳನ್ನು ಸೇರಿಸುವುದನ್ನು ಖಚಿತಪಡಿಸಿಕೊಳ್ಳಿ. 2. ನಿಮ್ಮ ದೇಹವನ್ನು ಸಕ್ರಿಯವಾಗಿ ಮತ್ತು ಸದೃಢವಾಗಿಡಲು ನಿಯಮಿತವಾಗಿ ವ್ಯಾಯಾಮ ಮಾಡಿ. 3. ಸಾಕಷ್ಟು ನಿದ್ರೆ ಪಡೆಯಿರಿ ಮತ್ತು ಸ್ಥಿರವಾದ ನಿದ್ರೆಯ ವೇಳಾಪಟ್ಟಿಯನ್ನು ಕಾಪಾಡಿಕೊಳ್ಳಿ.', 'role': 'assistant'}], 'text': '<|begin_of_text|><|start_header_id|>system<|end_header_id|>\n\nCutting Knowledge Date: December 2023\nToday Date: 01 Dec 2024\n\n<|eot_id|><|start_header_id|>user<|end_header_id|>\n\nಆರೋಗ್ಯವಾಗಿರಲು ಮೂರು ಸಲಹೆಗಳನ್ನು ನೀಡಿ.<|eot_id|><|start_header_id|>assistant<|end_header_id|>\n\n1.Eat ಸಮತೋಲಿತ ಆಹಾರ ಮತ್ತು ಸಾಕಷ್ಟು ಹಣ್ಣುಗಳು ಮತ್ತು ತರಕಾರಿಗಳನ್ನು ಸೇರಿಸುವುದನ್ನು ಖಚಿತಪಡಿಸಿಕೊಳ್ಳಿ. 2. ನಿಮ್ಮ ದೇಹವನ್ನು ಸಕ್ರಿಯವಾಗಿ ಮತ್ತು ಸದೃಢವಾಗಿಡಲು ನಿಯಮಿತವಾಗಿ ವ್ಯಾಯಾಮ ಮಾಡಿ. 3. ಸಾಕಷ್ಟು ನಿದ್ರೆ ಪಡೆಯಿರಿ ಮತ್ತು ಸ್ಥಿರವಾದ ನಿದ್ರೆಯ ವೇಳಾಪಟ್ಟಿಯನ್ನು ಕಾಪಾಡಿಕೊಳ್ಳಿ.<|eot_id|>'}

# %% [markdown]
# ## Training Configurations

# %%
from trl import SFTTrainer
from transformers import TrainingArguments, DataCollatorForSeq2Seq
from unsloth import is_bfloat16_supported
trainer = SFTTrainer(
 model = lora_layers_and_quantized_model, # only lora layers will be trained, and quantized base model will remain frozen
 tokenizer = tokenizer,
 train_dataset = dataset,
 dataset_text_field = "text",
 max_seq_length = max_seq_length,
 data_collator = DataCollatorForSeq2Seq(tokenizer = tokenizer),
 dataset_num_proc = 2,
 packing = False,
 args = TrainingArguments(
 per_device_train_batch_size = 4,
 gradient_accumulation_steps = 4,
 warmup_steps = 20,
 max_steps = 300,
 learning_rate = 1.5e-4,
 fp16 = not is_bfloat16_supported(),
 bf16 = is_bfloat16_supported(),
 logging_steps = 10,
 optim = "adamw_8bit",
 weight_decay = 0.02,
 lr_scheduler_type = "linear",
 seed = 3407,
 output_dir = "outputs",
 ),
)
# Out:
# Map (num_proc=2):   0%|          | 0/389608 [00:00<?, ? examples/s]

# %% [markdown]
# ## Model Training

# %%
from unsloth.chat_templates import train_on_responses_only
trainer = train_on_responses_only(
 trainer,
 instruction_part = "<|start_header_id|>user<|end_header_id|>\n\n",
 response_part = "<|start_header_id|>assistant<|end_header_id|>\n\n",
)
trainer_stats = trainer.train()
# Out:
# Map:   0%|          | 0/389608 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 389,608 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 4 | Gradient Accumulation steps = 4
# \        /    Total batch size = 16 | Total steps = 300
#  "-____-"     Number of trainable parameters = 24,313,856
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# ...

# %% [markdown]
# ## Inference

# %%
from unsloth import FastLanguageModel

"""
Model is not perfect at responding accurately, but i can see model has learned lot of nuances from data.
I only trained it on 300 steps on single epoch, model can be better, I am using free Google Colab. mine resources are limited
"""

# Prepare the model for Unsloth inference
finetuned_model = FastLanguageModel.for_inference(lora_layers_and_quantized_model)

# Define the input messages with explicit instruction to avoid system messages
messages = [
    {"role": "user", "content":"ಪರಿಸರದ ಬಗ್ಗೆ ಬರೆಯಿರಿ ಮತ್ತು ಪ್ರಬಂಧವನ್ನು ಬರೆಯಿರಿ."}
]

# Tokenize the input and get the attention mask
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize=True,
    add_generation_prompt=True,
    return_tensors="pt",  # Ensure it returns PyTorch tensors
).to("cuda")

# Extract input_ids and attention_mask
input_ids = inputs  # Assuming `inputs` is a tensor
attention_mask = (input_ids != tokenizer.pad_token_id).long()  # Create attention mask if missing

# Generate output using the model
outputs = finetuned_model.generate(
    input_ids=input_ids,
    attention_mask=attention_mask,  # Pass the attention mask here
    max_new_tokens=1024,
    use_cache=True,
    temperature=1.5,
    min_p=0.1
)

# Decode the output tokens
decoded_output = tokenizer.batch_decode(outputs, skip_special_tokens=True)

# Post-process to clean unwanted system messages
clean_output = []
for response in decoded_output:
    # Explicitly remove unwanted metadata patterns
    response = response.split("user\n\n")[1] if "user\n\n" in response else response
    response = response.split("assistant\n\n")[1] if "assistant\n\n" in response else response
    clean_output.append(response)

# Print the cleaned-up output (should now only contain the joke)
print(clean_output)
# Out:
# ['ಪ್ರತಿ ಜನರು ಪರಿಸರವನ್ನು ಸರಿದೂಗುವ ರೀತಿಯಲ್ಲಿ ಸುರಕ್ಷಿತವಾಗಿ ಆಯ್ಕೆ ಮಾಡಬೇಕು ಏಕೆಂದರೆ ಸಂಪನ್ಮೂಲಗಳಿಗಾಗಿ ಹೆಚ್ಚು ಉತ್ಪಾದಕ ಜನರಿಂದಾಗುವ ಚಾಲನೆಯು ಭೂಮಿಯನ್ನು ಸಮತಾಪ ಮಾಡಿದೆಯೇನು? ಪರಿಸರ ಕಾಲುವೆಗಳು ಸಂಚಾರ ವ್ಯವಸ್ಥೆಯನ್ನು ಹೇಗೆ ಕಡಿತ ಮಾಡುತ್ತದೆ? ಕಚಿಕೊಂಬಲ್ ಗದಿಗಳು ಹುದುಗಳು ಮತ್ತು ಹೋಳಗಳ ಮೇಲೆ ಭಾರವನ್ನು ಮೀಸಲಿಟುವಾಗ, ನೀವು ಹವಾಮಾನ ಬದಲಾವಣೆಯಿಂದ ಸುತ್ತಲಿನ ಪ್ರದೇಶದ ನವೀಕೃತಿಗಳನ್ನು ಮಿತಿಗೊಳಿಸಬೇಕು. ಎಚ್ಚರಿಕೆ ಮತ್ತು ಚಟುವಟಿಕೆ ಪ್ರಮುಖ ಗ್ಲಾಸ್ಗ್ಯಾವ್ ಗೆಲೆಗಳಿಂದ ರುಕ್ಷಕ ಚುನಾಯಿಗಳನ್ನು ಅನ್ವಯಿಸಿ. ಇತರರ ಮಾರ್ಗವನ್ನು ಗುರುತಿಸಿ, ನಾವು ಗಮನವನ್ನು ಕೇಂದ್ರೀಕರಿಸಿದ್ದ್ದರಿಂದ ಆ ಪ್ರದೇಶದ ಪ್ರಯೋಜನಗಳು ಕಡಿಮೆ ಮಾಡಿದ್ದ್ದರಿಂದ ಸಂಸ್ಥೆ ಆರ್ಥಿಕವಾಗಿ ಸ್ವಲ್ಪ ಬೆಂಬಲಿಗೆ ಸಾಮರ್ಥ್ಯಗಳನ್ನ']

# %% [markdown]
# ## Cleaning the RAM
#
# * if you need you can clean the RAM  before doing further operations, mine is working perfectly

# %%
# Check if 'model' is defined before attempting to delete it
if 'model' in locals() or 'model' in globals():
    del finetuned_model
# Check if 'pipe' is defined before attempting to delete it
if 'pipe' in locals() or 'pipe' in globals():
    del pipe
# Check if 'trainer' is defined before attempting to delete it
if 'trainer' in locals() or 'trainer' in globals():
    del trainer
import gc
import torch
gc.collect()

# %% [markdown]
# ## Saving the model and tokenizer

# %%
import os

# Define the path for saving the model
save_dir = "/content/model"
os.makedirs(save_dir, exist_ok=True)

print(f"Directory created: {save_dir}")
from transformers import AutoModelForCausalLM, AutoTokenizer

# Save the fine-tuned model
lora_layers_and_quantized_model.save_pretrained(save_dir)

# Save the tokenizer
tokenizer.save_pretrained(save_dir)

print(f"Model and tokenizer saved to {save_dir}")
# Out:
# Directory created: /content/model
# Model and tokenizer saved to /content/model

# %% [markdown]
# ## Merging base model and  finetuned lora layers

# %%
from unsloth import FastLanguageModel
from peft import PeftModel
import torch

# Base model setup
max_seq_length = 2048
finetuned_model = "/content/model"  # Path to the fine-tuned LoRA weights
dtype = None  # Auto detection of dtype
load_in_4bit = True  # Reduce memory usage with 4-bit quantization

# Load the base model or quantized_model and tokenizer
quantized_model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/Llama-3.2-3B-Instruct",
    max_seq_length=max_seq_length,
    dtype=dtype,
    load_in_4bit=load_in_4bit,
)

# Merge the LoRA weights into the base model
final_model = PeftModel.from_pretrained(quantized_model, finetuned_model)
final_model = final_model.merge_and_unload()  # Merge LoRA weights and unload any residual adapter layers

# Save the merged model and tokenizer
save_dir = "/content/merged_model"
final_model.save_pretrained(save_dir)
tokenizer.save_pretrained(save_dir)

print(f"Merged model and tokenizer saved to {save_dir}")
# Out:
# ==((====))==  Unsloth 2024.11.10: Fast Llama patching. Transformers:4.47.0.dev0.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu118. CUDA: 7.5. CUDA Toolkit: 11.8. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# /usr/local/lib/python3.10/dist-packages/peft/tuners/lora/bnb.py:336: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# Merged model and tokenizer saved to /content/merged_model

# %% [markdown]
# ## Pushing to HuggingFace

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# Log into Hugging Face
# !huggingface-cli login

# Push to Hugging Face Hub
# Use final_model, which is the merged and loaded model, instead of finetuned_model
final_model.push_to_hub("devshaheen/llama-3.2-3b-Instruct-finetune", check_pr=True)
tokenizer.push_to_hub("devshaheen/llama-3.2-3b-Instruct-finetune")
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# ...

# %% [markdown]
# ## Pushing to S3
# * Setting Credentials

# %%
import os

# Set AWS credentials as environment variables
os.environ["AWS_ACCESS_KEY_ID"] = "your aws access key"
os.environ["AWS_SECRET_ACCESS_KEY"] = "your aws serect access key"
os.environ["AWS_REGION"] = "e.g, us-east-1"

# %% [markdown]
# * Accessing Credentials

# %%
# Access stored secrets
aws_access_key_id = os.getenv("AWS_ACCESS_KEY_ID")
aws_secret_access_key = os.getenv("AWS_SECRET_ACCESS_KEY")
aws_region = os.getenv("AWS_REGION")

# Print (avoid printing sensitive info in real use)
print(f"AWS_ACCESS_KEY_ID: {aws_access_key_id}")
print(f"AWS_REGION: {aws_region}")
# Out:
# AWS_ACCESS_KEY_ID: AKIAWPPO6U54NR3WVTQD
# AWS_REGION: us-east-1

# %% [markdown]
# * Setting boto3 client

# %%
import boto3

s3_client = boto3.client(
    's3',
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=aws_region
)

# %% [markdown]
# * model uploading code

# %%
import boto3
import os

bucket_name = "instruct"
local_model_path = "/content/merged_model"  # Path where model and tokenizer files are stored locally
s3_folder_name = "files/"  # Folder to store model and tokenizer files in S3

# Initialize the S3 client (assuming you've already set up AWS credentials)
s3_client = boto3.client('s3')

# Function to upload specific model and tokenizer files to S3
def upload_files_to_s3(local_dir, s3_bucket, s3_prefix):
    for filename in os.listdir(local_dir):
        local_file_path = os.path.join(local_dir, filename)

        # Ensure that only the 'model.safetensors' and 'tokenizer.json' files are uploaded
        if filename == "model.safetensors" or filename == "tokenizer.json":
            s3_file_path = os.path.join(s3_prefix, filename)

            print(f"Uploading {local_file_path} to s3://{s3_bucket}/{s3_file_path}")
            s3_client.upload_file(local_file_path, s3_bucket, s3_file_path)
        else:
            print(f"Skipping {filename}, as it is not the model.safetensors or tokenizer.json file.")

# Upload only the model.safetensors and tokenizer.json files to S3
upload_files_to_s3(local_model_path, bucket_name, s3_folder_name)
# Out:
# Skipping tokenizer_config.json, as it is not the model.safetensors or tokenizer.json file.
# Skipping special_tokens_map.json, as it is not the model.safetensors or tokenizer.json file.
# Uploading /content/merged_model/tokenizer.json to s3://instruct/files/tokenizer.json
# Uploading /content/merged_model/model.safetensors to s3://instruct/files/model.safetensors
# Skipping config.json, as it is not the model.safetensors or tokenizer.json file.
# Skipping generation_config.json, as it is not the model.safetensors or tokenizer.json file.
